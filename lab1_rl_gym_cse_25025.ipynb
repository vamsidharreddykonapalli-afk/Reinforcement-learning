# %% [markdown]
# # Lab Task 1 — Reinforcement Learning Laboratory
# ## Experiment 1: Exploring Reinforcement Learning Environments using Gymnasium
#
#
#
# This notebook covers:
# 1. Environment Setup
# 2. Create and Initialize an RL Environment
# 3. Explore Observation and Action Spaces
# 4. Execute a Random Agent

# %% [markdown]
# ## Task 1: Environment Setup
# - Install Gymnasium, NumPy, and Matplotlib.
# - Import the required libraries.
# - Verify the installation by printing the Gymnasium version.

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

print(f"Gymnasium version: {gym.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# Gymnasium version: 1.3.0
# NumPy version: 2.0.2

# %% [markdown]
# ## Task 2: Create and Initialize an RL Environment
# - Create the CartPole-v1 environment.
# - Reset the environment.
# - Display the initial observation and environment information.

# %%
env = gym.make("CartPole-v1")

# Reset the environment (returns initial observation + info dict)
observation, info = env.reset(seed=42)

print("Initial Observation:", observation)
print("Info:", info)
print("Environment Spec:", env.spec)
print("Metadata:", env.metadata)
# Out:
# Initial Observation: [ 0.0273956  -0.00611216  0.03585979  0.0197368 ]
# Info: {}
# Environment Spec: EnvSpec(id='CartPole-v1', entry_point='gymnasium.envs.classic_control.cartpole:CartPoleEnv', reward_threshold=475.0, nondeterministic=False, max_episode_steps=500, order_enforce=True, disable_env_checker=False, kwargs={}, namespace=None, name='CartPole', version=1, additional_wrappers=(), vector_entry_point='gymnasium.envs.classic_control.cartpole:CartPoleVectorEnv')
# Metadata: {'render_modes': ['human', 'rgb_array'], 'render_fps': 50}

# %% [markdown]
# ## Task 3: Explore Observation and Action Spaces
# - Display the observation space.
# - Display the action space.
# - Display the type of observation space.
# - Display the number of possible actions.

# %%
print("Observation Space:", env.observation_space)
print("Action Space:", env.action_space)
print("Type of Observation Space:", type(env.observation_space))
print("Number of possible actions:", env.action_space.n)

# Extra useful details
print("Observation Space Low:", env.observation_space.low)
print("Observation Space High:", env.observation_space.high)
# Out:
# Observation Space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Action Space: Discrete(2)
# Type of Observation Space: <class 'gymnasium.spaces.box.Box'>
# Number of possible actions: 2
# Observation Space Low: [-4.8               -inf -0.41887903        -inf]
# Observation Space High: [4.8               inf 0.41887903        inf]

# %% [markdown]
# ## Task 4: Execute a Random Agent
# - Execute a random action at every time step.
# - Run the environment for one complete episode.
# - Print step number, selected action, observation, reward, and episode status.
# - Display the total number of steps and cumulative reward.

# %%
observation, info = env.reset(seed=42)

step_count = 0
total_reward = 0
terminated = False
truncated = False

while not (terminated or truncated):
    # Sample a random action from the action space
    action = env.action_space.sample()

    # Execute the action in the environment
    observation, reward, terminated, truncated, info = env.step(action)

    step_count += 1
    total_reward += reward

    print(f"Step: {step_count:3d} | Action: {action} | "
          f"Observation: {np.round(observation, 3)} | "
          f"Reward: {reward} | Terminated: {terminated} | Truncated: {truncated}")

print("\n--- Episode Summary ---")
print(f"Total steps taken: {step_count}")
print(f"Cumulative reward: {total_reward}")

env.close()
# Out:
# Step:   1 | Action: 0 | Observation: [ 0.027 -0.202  0.036  0.324] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:   2 | Action: 1 | Observation: [ 0.023 -0.007  0.043  0.042] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:   3 | Action: 0 | Observation: [ 0.023 -0.203  0.044  0.348] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:   4 | Action: 0 | Observation: [ 0.019 -0.399  0.051  0.654] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:   5 | Action: 0 | Observation: [ 0.011 -0.594  0.064  0.963] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:   6 | Action: 1 | Observation: [-0.001 -0.4    0.083  0.691] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:   7 | Action: 1 | Observation: [-0.009 -0.206  0.097  0.425] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:   8 | Action: 1 | Observation: [-0.013 -0.013  0.105  0.164] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:   9 | Action: 0 | Observation: [-0.013 -0.209  0.108  0.488] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:  10 | Action: 0 | Observation: [-0.017 -0.406  0.118  0.813] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:  11 | Action: 1 | Observation: [-0.025 -0.212  0.135  0.56 ] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:  12 | Action: 1 | Observation: [-0.03  -0.019  0.146  0.312] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:  13 | Action: 0 | Observation: [-0.03  -0.216  0.152  0.647] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:  14 | Action: 1 | Observation: [-0.034 -0.023  0.165  0.406] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:  15 | Action: 0 | Observation: [-0.035 -0.22   0.173  0.746] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:  16 | Action: 0 | Observation: [-0.039 -0.417  0.188  1.088] | Reward: 1.0 | Terminated: False | Truncated: False
# Step:  17 | Action: 0 | Observation: [-0.048 -0.614  0.21   1.433] | Reward: 1.0 | Terminated: True | Truncated: False
#
# --- Episode Summary ---
# Total steps taken: 17
# Cumulative reward: 17.0
